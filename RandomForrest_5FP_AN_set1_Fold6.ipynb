# %%
import os
import numpy as np
import pandas as pd
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVtrain_5FP_fold6_1.csv') #เปลี่ยนไฟล์
dataframe = dataframe.drop(['Unnamed: 0'], axis=1)
dataframe
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.364294  0.100958 -0.141095  0.008378  0.197379 -0.003850 -0.163205
# 1     0.117332  0.206312  0.072082 -0.124712  0.373150 -0.047873  0.689254
# 2    -0.092090 -0.112679 -0.137555 -0.125217  0.211316 -0.166280  0.577107
# 3    -0.056883 -0.137370 -0.065180  0.048629  0.233246  0.130619 -0.207292
# 4     0.612515  0.137323 -0.140400  0.031721  0.573213  0.200964 -0.153633
# ...        ...       ...       ...       ...       ...       ...       ...
# 4594  0.588413 -0.033786 -0.194639 -0.088500 -0.029469 -0.164584 -0.211117
# 4595  0.117491 -0.037146 -0.160026 -0.087072  0.348644  0.078493 -0.194041
# 4596 -0.184211 -0.178187  0.182524  0.152978 -0.195437 -0.187907 -0.164389
# 4597 -0.189938 -0.111346 -0.058149  0.334833  0.057391 -0.154338 -0.117801
# 4598  0.089509 -0.169227 -0.208234 -0.187207  0.641838 -0.191079 -0.225486
#
#              7         8         9  ...      2042      2043      2044  \
# 0     0.283486 -0.120220  0.428233  ...  0.377151  1.067846  0.699513
# 1     0.416436 -0.104231  0.352352  ... -0.067163  0.475113  0.304593
# 2     0.025931 -0.146537 -0.008648  ... -0.170188  0.056256 -0.028722
# 3     0.776245  0.119973 -0.022267  ... -0.053838  0.447754  0.430569
# 4     0.962362  0.086050  0.814025  ...  0.111319  1.048282  1.179006
# ...        ...       ...       ...  ...       ...       ...       ...
# 4594  0.391163 -0.162890  0.636100  ... -0.063470  0.604752  0.851983
# 4595  0.762906  0.247675  0.383848  ...  0.181548  0.471561  0.926297
# 4596  0.027783  0.856146 -0.227562  ... -0.162945 -0.167645 -0.185876
# 4597  0.284321  0.823372 -0.058138  ... -0.068496 -0.118340 -0.145341
# 4598 -0.028562  0.397155  0.160737  ... -0.066720  0.478478  0.170738
#
#           2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0    -0.109622  0.265392  0.788433  Abnormal          P31   FP-B       AB01
# 1    -0.125455 -0.142197  0.372518  Abnormal           P1   FP-A       AB01
# 2    -0.121274 -0.189222  0.195729  Abnormal           P2   FP-A       AB01
# 3    -0.038273  0.413446  0.417263  Abnormal          P42   FP-B       AB01
# 4    -0.114935  0.528234  0.912156  Abnormal          P41   FP-B       AB01
# ...        ...       ...       ...       ...          ...    ...        ...
# 4594 -0.151965 -0.007454  0.566837    Normal          P32   FP-B     Normal
# 4595 -0.114032  0.485462  0.566014    Normal          P42   FP-B     Normal
# 4596  0.800626  0.573581 -0.166318    Normal          P52   FP-C     Normal
# 4597  0.745258  0.703724 -0.134604    Normal          P61   FP-C     Normal
# 4598 -0.085297 -0.241464  0.687300    Normal           P8   FP-E     Normal
#
# [4599 rows x 2052 columns]

# %%
X = dataframe.iloc[:,0:2048]
y = dataframe.iloc[:,2048]
print(X.shape)
print(y.shape)
# Out:
# (4599, 2048)
# (4599,)

# %%
y[0]
# Out:
# 'Abnormal'

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier

# %%
n_estimators = [400]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100] 

forest = RandomForestClassifier(random_state = 1)


hyperF ={'n_estimators' : n_estimators, 'max_depth' : max_depth, 'min_samples_split' : min_samples_split}
# hyperF ={'max_depth' : max_depth, 'min_samples_split' : min_samples_split}

gridF = GridSearchCV(forest, hyperF, cv = 10, verbose = 1, n_jobs = -1)
bestF = gridF.fit(X, y)
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits

# %%
# view the results as a pandas DataFrame
import pandas as pd
pd.DataFrame(bestF.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#     mean_test_score  std_test_score  \
# 0          0.724483        0.037598
# 1          0.726658        0.038306
# 2          0.722526        0.038452
# 3          0.723177        0.041313
# 4          0.718829        0.040763
# 5          0.773826        0.061430
# 6          0.775351        0.058571
# 7          0.775784        0.061034
# 8          0.776218        0.062599
# 9          0.759043        0.057366
# 10         0.797306        0.069009
# 11         0.795351        0.064887
# 12         0.799699        0.066126
# 13         0.799265        0.065008
# 14         0.773169        0.068693
# 15         0.801649        0.076665
# 16         0.799698        0.068441
# 17         0.798393        0.069673
# 18         0.801218        0.071225
# 19         0.775998        0.066238
# 20         0.804043        0.072674
# 21         0.799915        0.068773
# 22         0.798829        0.067723
# 23         0.799043        0.072444
# 24         0.776650        0.067263
#
#                                                params
# 0   {'max_depth': 5, 'min_samples_split': 2, 'n_es...
# 1   {'max_depth': 5, 'min_samples_split': 5, 'n_es...
# 2   {'max_depth': 5, 'min_samples_split': 10, 'n_e...
# 3   {'max_depth': 5, 'min_samples_split': 15, 'n_e...
# 4   {'max_depth': 5, 'min_samples_split': 100, 'n_...
# 5   {'max_depth': 8, 'min_samples_split': 2, 'n_es...
# 6   {'max_depth': 8, 'min_samples_split': 5, 'n_es...
# 7   {'max_depth': 8, 'min_samples_split': 10, 'n_e...
# 8   {'max_depth': 8, 'min_samples_split': 15, 'n_e...
# 9   {'max_depth': 8, 'min_samples_split': 100, 'n_...
# 10  {'max_depth': 15, 'min_samples_split': 2, 'n_e...
# 11  {'max_depth': 15, 'min_samples_split': 5, 'n_e...
# 12  {'max_depth': 15, 'min_samples_split': 10, 'n_...
# 13  {'max_depth': 15, 'min_samples_split': 15, 'n_...
# 14  {'max_depth': 15, 'min_samples_split': 100, 'n...
# 15  {'max_depth': 25, 'min_samples_split': 2, 'n_e...
# 16  {'max_depth': 25, 'min_samples_split': 5, 'n_e...
# 17  {'max_depth': 25, 'min_samples_split': 10, 'n_...
# 18  {'max_depth': 25, 'min_samples_split': 15, 'n_...
# 19  {'max_depth': 25, 'min_samples_split': 100, 'n...
# 20  {'max_depth': 30, 'min_samples_split': 2, 'n_e...
# 21  {'max_depth': 30, 'min_samples_split': 5, 'n_e...
# 22  {'max_depth': 30, 'min_samples_split': 10, 'n_...
# 23  {'max_depth': 30, 'min_samples_split': 15, 'n_...
# 24  {'max_depth': 30, 'min_samples_split': 100, 'n...

# %%
# examine the first result
print("**examine the first result","\n")

print(bestF.cv_results_['params'][0])
print(bestF.cv_results_['mean_test_score'][0])

# print the array of mean scores only
print("\n","**print the array of mean scores only","\n")

grid_mean_scores = bestF.cv_results_['mean_test_score']
print(grid_mean_scores)

# examine the best model
print("\n","**examine the best model","\n")

print(bestF.best_score_)
print(bestF.best_params_)
print(bestF.best_estimator_)
# Out:
# **examine the first result
#
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}
# 0.7244832812351994
#
#  **print the array of mean scores only
#
# [0.72448328 0.72665767 0.72252581 0.72317657 0.71882874 0.77382637
#  0.77535095 0.77578384 0.77621815 0.75904282 0.79730558 0.79535095
#  0.79969878 0.79926542 0.77316946 0.80164867 0.7996983  0.79839254
#  0.80121815 0.77599792 0.80404282 0.79991522 0.79882874 0.79904282
#  0.77664962]
#
#  **examine the best model
#
# 0.8040428151937103
# {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 400}
# RandomForestClassifier(max_depth=30, n_estimators=400, random_state=1)

# %%
#Print the tured parameters and score
print("Tuned Decision Tree Parameters: {}".format(bestF.best_params_))
print("Best score is {}".format(bestF.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'max_depth': 30, 'min_samples_split': 2, 'n_estimators': 400}
# Best score is 0.8040428151937103

# %% [markdown]
# # setting parameters

# %%
forestOpt = RandomForestClassifier(random_state = 1, max_depth = 30, n_estimators = 400, min_samples_split = 2) #เปลี่ยนตาม cell 8
             
modelOpt = forestOpt.fit(X, y)#

# %%
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVvalidation_5FP_RF_5FP_fold6_1.csv') #เปลี่ยนชื่อไฟล์ Validation

# %%
dataframe
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0             0  0.088111  0.084979 -0.159341 -0.121146  0.108318  0.055693
# 1             1 -0.036043  0.176504  0.406563 -0.057735  0.059977  0.076648
# 2             2 -0.201366 -0.125678 -0.081618  0.060315 -0.203556 -0.190703
# 3             3  0.229069  0.040427 -0.096845  0.212402  0.290006 -0.223279
# 4             4  0.098194 -0.125541 -0.193168 -0.103063  0.069133 -0.095026
# ..          ...       ...       ...       ...       ...       ...       ...
# 653         653  0.135335 -0.133799 -0.121256 -0.070816  0.102646 -0.168273
# 654         654 -0.008360 -0.063737 -0.107836  0.031093  0.314323 -0.106467
# 655         655 -0.173923  0.044043  0.087345  0.198223 -0.221117 -0.159845
# 656         656 -0.214644  0.075535 -0.006698 -0.053203 -0.189083 -0.182044
# 657         657 -0.078499  0.000315 -0.216394 -0.031782  0.196690 -0.197217
#
#             6         7         8  ...      2042      2043      2044  \
# 0   -0.206385  0.670532  0.161083  ... -0.006836  0.428255  0.634549
# 1    0.514208  0.203904 -0.197568  ... -0.092788  0.047489  0.043831
# 2   -0.189451 -0.046204  0.128575  ... -0.211645 -0.222409 -0.213920
# 3    0.664260  0.584298 -0.120318  ... -0.117410  0.065853  0.108393
# 4   -0.110996  0.384701 -0.191665  ... -0.142851  0.520026  0.513894
# ..        ...       ...       ...  ...       ...       ...       ...
# 653 -0.107410  0.416860 -0.037102  ... -0.189302  0.464991  0.726382
# 654 -0.205384  0.576752 -0.048196  ...  0.005061  0.131541  0.319574
# 655 -0.013978 -0.045500  0.718877  ...  0.099829 -0.169990 -0.175388
# 656 -0.178347  0.151136  0.400567  ... -0.182873 -0.118322 -0.210180
# 657 -0.215897 -0.223079  0.026445  ... -0.041417 -0.183563 -0.202454
#
#          2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0   -0.079291  0.253597  0.368813  Abnormal          P42   FP-B       AB01
# 1   -0.124892 -0.151274  0.160443  Abnormal           P2   FP-A       AB01
# 2    0.206031 -0.049139 -0.162657  Abnormal          P51   FP-C       AB01
# 3   -0.093355 -0.220048  0.243307  Abnormal           P1   FP-A       AB01
# 4    0.154666  0.113198  0.568250  Abnormal          P41   FP-B       AB01
# ..        ...       ...       ...       ...          ...    ...        ...
# 653 -0.010262  0.267716  0.228705    Normal          P32   FP-B     Normal
# 654 -0.147122  0.105844  0.376450    Normal          P42   FP-B     Normal
# 655  0.639044  0.319324 -0.158037    Normal          P52   FP-C     Normal
# 656  0.482659  0.413239 -0.157191    Normal          P61   FP-C     Normal
# 657 -0.120677 -0.197190  0.083118    Normal           P8   FP-E     Normal
#
# [658 rows x 2053 columns]

# %%
X_test = dataframe.iloc[:,1:2049]
y_test = dataframe.iloc[:,2049]
print(X_test.shape)
print(y_test.shape)
# Out:
# (658, 2048)
# (658,)

# %%
y_test
# Out:
# 0      Abnormal
# 1      Abnormal
# 2      Abnormal
# 3      Abnormal
# 4      Abnormal
#          ...
# 653      Normal
# 654      Normal
# 655      Normal
# 656      Normal
# 657      Normal
# Name: Class, Length: 658, dtype: object

# %%
y_pred = modelOpt.predict(X_test)

# %%
#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))#performance
# Out:
# [[130  99]
#  [ 24 405]]
#               precision    recall  f1-score   support
#
#     Abnormal       0.84      0.57      0.68       229
#       Normal       0.80      0.94      0.87       429
#
#     accuracy                           0.81       658
#    macro avg       0.82      0.76      0.77       658
# weighted avg       0.82      0.81      0.80       658

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
TN, FP, FN, TP = confusion_matrix(y_test, y_pred).ravel()
print(TN, FP, FN, TP)
# Out:
# 130 99 24 405

# %% [markdown]
# # Save Model

# %%
#Save Model

import pickle
os.chdir('/media/tohn/SSD/ModelTrainByImages/R2_6/models/')
filename = "modelrf_5FP_AN_fold6_1.pkl" #เปลี่ยนชื่อไฟล์ Train random forest
with open(filename, 'wb') as file:
    pickle.dump(modelOpt, file)

# %%
# #load model

# with open(filename, 'rb') as file:
#     model = pickle.load(file)
