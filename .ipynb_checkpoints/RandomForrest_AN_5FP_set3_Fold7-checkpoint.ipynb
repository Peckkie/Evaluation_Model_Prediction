rows x 2052 columns]

# %%
X = dataframe.iloc[:,0:2048]
y = dataframe.iloc[:,2050]
print(X.shape)
print(y.shape)
# Out:
# (7320, 2048)
# (7320,)

# %%
y[0]
# Out:
# 'FP-A'

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier

# %%
n_estimators = [400]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100] 

forest = RandomForestClassifier(random_state = 1)


hyperF ={'n_estimators' : n_estimators, 'max_depth' : max_depth, 'min_samples_split' : min_samples_split}
# hyperF ={'max_depth' : max_depth, 'min_samples_split' : min_samples_split}

gridF = GridSearchCV(forest, hyperF, cv = 10, verbose = 1, n_jobs = -1)
bestF = gridF.fit(X, y)
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits

# %%
# view the results as a pandas DataFrame
import pandas as pd
pd.DataFrame(bestF.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#     mean_test_score  std_test_score  \
# 0          0.529918        0.095469
# 1          0.530055        0.098220
# 2          0.526776        0.097266
# 3          0.528279        0.098406
# 4          0.512158        0.095391
# 5          0.710519        0.130518
# 6          0.704918        0.129315
# 7          0.700546        0.126843
# 8          0.693033        0.126222
# 9          0.610656        0.117593
# 10         0.814481        0.123686
# 11         0.810383        0.127910
# 12         0.810792        0.126953
# 13         0.809153        0.128282
# 14         0.690574        0.132094
# 15         0.815847        0.126144
# 16         0.817486        0.123964
# 17         0.816257        0.123496
# 18         0.813934        0.124661
# 19         0.702869        0.135727
# 20         0.816393        0.127974
# 21         0.818579        0.124917
# 22         0.816393        0.123380
# 23         0.813388        0.125901
# 24         0.703279        0.136617
#
#                                                params
# 0   {'max_depth': 5, 'min_samples_split': 2, 'n_es...
# 1   {'max_depth': 5, 'min_samples_split': 5, 'n_es...
# 2   {'max_depth': 5, 'min_samples_split': 10, 'n_e...
# 3   {'max_depth': 5, 'min_samples_split': 15, 'n_e...
# 4   {'max_depth': 5, 'min_samples_split': 100, 'n_...
# 5   {'max_depth': 8, 'min_samples_split': 2, 'n_es...
# 6   {'max_depth': 8, 'min_samples_split': 5, 'n_es...
# 7   {'max_depth': 8, 'min_samples_split': 10, 'n_e...
# 8   {'max_depth': 8, 'min_samples_split': 15, 'n_e...
# 9   {'max_depth': 8, 'min_samples_split': 100, 'n_...
# 10  {'max_depth': 15, 'min_samples_split': 2, 'n_e...
# 11  {'max_depth': 15, 'min_samples_split': 5, 'n_e...
# 12  {'max_depth': 15, 'min_samples_split': 10, 'n_...
# 13  {'max_depth': 15, 'min_samples_split': 15, 'n_...
# 14  {'max_depth': 15, 'min_samples_split': 100, 'n...
# 15  {'max_depth': 25, 'min_samples_split': 2, 'n_e...
# 16  {'max_depth': 25, 'min_samples_split': 5, 'n_e...
# 17  {'max_depth': 25, 'min_samples_split': 10, 'n_...
# 18  {'max_depth': 25, 'min_samples_split': 15, 'n_...
# 19  {'max_depth': 25, 'min_samples_split': 100, 'n...
# 20  {'max_depth': 30, 'min_samples_split': 2, 'n_e...
# 21  {'max_depth': 30, 'min_samples_split': 5, 'n_e...
# 22  {'max_depth': 30, 'min_samples_split': 10, 'n_...
# 23  {'max_depth': 30, 'min_samples_split': 15, 'n_...
# 24  {'max_depth': 30, 'min_samples_split': 100, 'n...

# %%
# examine the first result
print("**examine the first result","\n")

print(bestF.cv_results_['params'][0])
print(bestF.cv_results_['mean_test_score'][0])

# print the array of mean scores only
print("\n","**print the array of mean scores only","\n")

grid_mean_scores = bestF.cv_results_['mean_test_score']
print(grid_mean_scores)

# examine the best model
print("\n","**examine the best model","\n")

print(bestF.best_score_)
print(bestF.best_params_)
print(bestF.best_estimator_)
# Out:
# **examine the first result
#
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}
# 0.5299180327868853
#
#  **print the array of mean scores only
#
# [0.52991803 0.53005464 0.52677596 0.52827869 0.51215847 0.71051913
#  0.70491803 0.70054645 0.69303279 0.61065574 0.81448087 0.81038251
#  0.81079235 0.80915301 0.69057377 0.81584699 0.81748634 0.81625683
#  0.81393443 0.70286885 0.81639344 0.81857923 0.81639344 0.81338798
#  0.70327869]
#
#  **examine the best model
#
# 0.8185792349726777
# {'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 400}
# RandomForestClassifier(max_depth=30, min_samples_split=5, n_estimators=400,
#                        random_state=1)

# %%
#Print the tured parameters and score
print("Tuned Decision Tree Parameters: {}".format(bestF.best_params_))
print("Best score is {}".format(bestF.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'max_depth': 30, 'min_samples_split': 5, 'n_estimators': 400}
# Best score is 0.8185792349726777

# %% [markdown]
# # setting parameters

# %%
forestOpt = RandomForestClassifier(random_state = 1, max_depth = 30, n_estimators = 400, min_samples_split = 5) #เปลี่ยนตาม cell 8
             
modelOpt = forestOpt.fit(X, y)#

# %%
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVvalidation_AN_RF_AN_fold7_3.csv') #เปลี่ยนชื่อไฟล์ Validation

# %%
dataframe
# Out:
#       Unnamed: 0         0         1         2         3         4         5  \
# 0              0 -0.155259 -0.179418  0.177402  0.470569 -0.189734 -0.221299
# 1              1 -0.163393  0.091655 -0.129197 -0.129003 -0.061019 -0.217985
# 2              2 -0.146642 -0.065639 -0.121923  0.078993 -0.212230 -0.181396
# 3              3 -0.010863 -0.068397 -0.076694  0.086390 -0.085575 -0.090764
# 4              4 -0.053581 -0.070526  0.052108  0.135258 -0.090246 -0.099231
# ...          ...       ...       ...       ...       ...       ...       ...
# 1053        1053  0.044761  0.765506 -0.182560 -0.153772  0.213677  0.567514
# 1054        1054 -0.141355  0.053651 -0.197149 -0.087201  0.336112  0.261595
# 1055        1055  0.687790  0.932081 -0.168781  0.041376  0.795956  1.141080
# 1056        1056  0.044761  0.765506 -0.182560 -0.153772  0.213677  0.567514
# 1057        1057 -0.118950  0.550624 -0.170489 -0.116363  0.375816 -0.158195
#
#              6         7         8  ...      2042      2043      2044  \
# 0     0.162996 -0.189721 -0.220627  ... -0.200259  0.031554 -0.025925
# 1     0.006068 -0.028274 -0.065155  ...  0.042246 -0.064836 -0.124081
# 2     0.099635 -0.140027 -0.050937  ... -0.197151  0.034495  0.430760
# 3     0.286853 -0.100185  0.055757  ... -0.206130 -0.108709  0.387218
# 4     0.174165 -0.054822 -0.117625  ... -0.061941 -0.195151 -0.038029
# ...        ...       ...       ...  ...       ...       ...       ...
# 1053 -0.167241  0.206704  0.495684  ...  0.534003 -0.197093 -0.144643
# 1054 -0.173413 -0.042208  0.143733  ...  0.136451 -0.169053 -0.086879
# 1055 -0.138899  1.069099  0.790001  ...  1.212970 -0.170099  0.015881
# 1056 -0.167241  0.206704  0.495684  ...  0.534003 -0.197093 -0.144643
# 1057 -0.215680  0.034860  0.400545  ...  0.227038 -0.154780 -0.156515
#
#           2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0     0.326748  0.176144 -0.142380  Abnormal           P1   FP-A       AB02
# 1    -0.164816 -0.043753 -0.083989  Abnormal           P1   FP-A       AB04
# 2     0.208715  0.132236 -0.153242  Abnormal           P1   FP-A       AB05
# 3    -0.001178  0.092962 -0.175927  Abnormal           P1   FP-A       AB06
# 4    -0.118949 -0.055010  0.028432  Abnormal           P1   FP-A       AB01
# ...        ...       ...       ...       ...          ...    ...        ...
# 1053 -0.065134 -0.017054  0.254385    Normal           P8   FP-E     Normal
# 1054 -0.140537 -0.182326  0.114861    Normal           P8   FP-E     Normal
# 1055  0.084117 -0.069028  0.520883    Normal           P8   FP-E     Normal
# 1056 -0.065134 -0.017054  0.254385    Normal           P8   FP-E     Normal
# 1057 -0.168938 -0.055507 -0.034607    Normal           P8   FP-E     Normal
#
# [1058 rows x 2053 columns]

# %%
X_test = dataframe.iloc[:,1:2049]
y_test = dataframe.iloc[:,2051]
print(X_test.shape)
print(y_test.shape)
# Out:
# (1058, 2048)
# (1058,)

# %%
y_test
# Out:
# 0       FP-A
# 1       FP-A
# 2       FP-A
# 3       FP-A
# 4       FP-A
#         ...
# 1053    FP-E
# 1054    FP-E
# 1055    FP-E
# 1056    FP-E
# 1057    FP-E
# Name: Views, Length: 1058, dtype: object

# %%
y_pred = modelOpt.predict(X_test)

# %%
#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))#performance
# Out:
# [[ 77  81  30   2   0]
#  [ 16 281  14   0   5]
#  [  3 112 199   8   0]
#  [  0  29  45 110   0]
#  [  0  11   2   0  33]]
#               precision    recall  f1-score   support
#
#         FP-A       0.80      0.41      0.54       190
#         FP-B       0.55      0.89      0.68       316
#         FP-C       0.69      0.62      0.65       322
#         FP-D       0.92      0.60      0.72       184
#         FP-E       0.87      0.72      0.79        46
#
#     accuracy                           0.66      1058
#    macro avg       0.76      0.65      0.68      1058
# weighted avg       0.71      0.66      0.66      1058

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %% [markdown]
# # Save Model

# %%
#Save Model

import pickle
os.chdir('/media/tohn/SSD/ModelTrainByImages/R2_7/models/')
filename = "modelrf_AN_5FP_fold7_3.pkl" #เปลี่ยนชื่อไฟล์ Train random forest
with open(filename, 'wb') as file:
    pickle.dump(modelOpt, file)

# %%
# #load model

# with open(filename, 'rb') as file:
#     model = pickle.load(file)
