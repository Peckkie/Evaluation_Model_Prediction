# %%
import os
import numpy as np
import pandas as pd
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVtrain_5FP_fold8_1.csv') #เปลี่ยนไฟล์
dataframe = dataframe.drop(['Unnamed: 0'], axis=1)
dataframe
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.449174 -0.204428 -0.199144 -0.157085 -0.118373 -0.122697 -0.195651
# 1     0.359008  0.720912  0.315710  0.268273  0.106144  0.100688  0.846621
# 2     0.055149  0.511524 -0.003771  0.241515  0.240965 -0.129346  0.678433
# 3     0.061421 -0.197331 -0.155033 -0.128618 -0.084117 -0.110935 -0.195612
# 4     0.544007 -0.196851 -0.154777 -0.131862 -0.012534  0.045621 -0.210399
# ...        ...       ...       ...       ...       ...       ...       ...
# 4596  0.601950 -0.215200 -0.210370 -0.084321 -0.041753 -0.034182 -0.205843
# 4597  0.705719 -0.216591 -0.155282 -0.144300  0.076284  0.139908 -0.180171
# 4598 -0.182287 -0.208579  0.432112  0.227209  0.694599 -0.129581  0.495339
# 4599 -0.177720 -0.211180 -0.022040  0.163384  0.268721 -0.158802 -0.198402
# 4600 -0.022518 -0.214009 -0.220617 -0.177041  0.366825 -0.212835 -0.212763
#
#              7         8         9  ...      2042      2043      2044  \
# 0     0.409199  0.039756  0.521029  ... -0.208558  0.898302  0.243205
# 1     0.480937  0.157924  0.247229  ... -0.190041  0.451685  0.358777
# 2    -0.003770 -0.143136 -0.078084  ... -0.197617  0.107274  0.133976
# 3     0.350846 -0.011851  0.139456  ... -0.211585  0.424843  0.262484
# 4     0.362736 -0.048656  0.457716  ... -0.221963  0.417165  0.224456
# ...        ...       ...       ...  ...       ...       ...       ...
# 4596  0.408583 -0.135126  0.623134  ... -0.160655  0.743273  0.685318
# 4597  0.417639  0.011849  0.538739  ... -0.148911  0.498000  0.623234
# 4598  0.077959  0.950621 -0.204977  ...  0.927064 -0.109220 -0.124952
# 4599  0.095069  0.184693 -0.048553  ...  0.521852 -0.091544 -0.129625
# 4600 -0.200571  0.209188  0.219761  ... -0.094730  0.229632 -0.025232
#
#           2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0     0.095137  0.053012  0.387212  Abnormal          P31   FP-B       AB01
# 1     0.006070 -0.016088  0.272072  Abnormal           P1   FP-A       AB01
# 2    -0.070413 -0.222970  0.438487  Abnormal           P2   FP-A       AB01
# 3     0.229328 -0.024867  0.186694  Abnormal          P42   FP-B       AB01
# 4     0.247668  0.056598  0.158641  Abnormal          P41   FP-B       AB01
# ...        ...       ...       ...       ...          ...    ...        ...
# 4596  0.032199 -0.094300  0.028544    Normal          P32   FP-B     Normal
# 4597 -0.094777 -0.000488  0.484960    Normal          P42   FP-B     Normal
# 4598  0.670893  0.495636 -0.110583    Normal          P52   FP-C     Normal
# 4599  0.250234  0.631476 -0.143954    Normal          P61   FP-C     Normal
# 4600  0.589494 -0.220452  0.721964    Normal           P8   FP-E     Normal
#
# [4601 rows x 2052 columns]

# %%
X = dataframe.iloc[:,0:2048]
y = dataframe.iloc[:,2050]
print(X.shape)
print(y.shape)
# Out:
# (4601, 2048)
# (4601,)

# %%
y[0]
# Out:
# 'FP-B'

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier

# %%
n_estimators = [400]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100] 

forest = RandomForestClassifier(random_state = 1)


hyperF ={'n_estimators' : n_estimators, 'max_depth' : max_depth, 'min_samples_split' : min_samples_split}
# hyperF ={'max_depth' : max_depth, 'min_samples_split' : min_samples_split}

gridF = GridSearchCV(forest, hyperF, cv = 10, verbose = 1, n_jobs = -1)
bestF = gridF.fit(X, y)
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits

# %%
# view the results as a pandas DataFrame
import pandas as pd
pd.DataFrame(bestF.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#     mean_test_score  std_test_score  \
# 0          0.987828        0.018756
# 1          0.988046        0.018783
# 2          0.987612        0.018752
# 3          0.987176        0.018535
# 4          0.987828        0.018731
# 5          0.987828        0.018756
# 6          0.987828        0.018731
# 7          0.987394        0.018721
# 8          0.987394        0.018721
# 9          0.988045        0.018783
# 10         0.987394        0.018721
# 11         0.987176        0.018662
# 12         0.987176        0.018662
# 13         0.987394        0.018671
# 14         0.987828        0.018731
# 15         0.987176        0.018586
# 16         0.987176        0.018662
# 17         0.987176        0.018662
# 18         0.987394        0.018671
# 19         0.987828        0.018731
# 20         0.987176        0.018586
# 21         0.987176        0.018662
# 22         0.987176        0.018662
# 23         0.987394        0.018671
# 24         0.987828        0.018731
#
#                                                params
# 0   {'max_depth': 5, 'min_samples_split': 2, 'n_es...
# 1   {'max_depth': 5, 'min_samples_split': 5, 'n_es...
# 2   {'max_depth': 5, 'min_samples_split': 10, 'n_e...
# 3   {'max_depth': 5, 'min_samples_split': 15, 'n_e...
# 4   {'max_depth': 5, 'min_samples_split': 100, 'n_...
# 5   {'max_depth': 8, 'min_samples_split': 2, 'n_es...
# 6   {'max_depth': 8, 'min_samples_split': 5, 'n_es...
# 7   {'max_depth': 8, 'min_samples_split': 10, 'n_e...
# 8   {'max_depth': 8, 'min_samples_split': 15, 'n_e...
# 9   {'max_depth': 8, 'min_samples_split': 100, 'n_...
# 10  {'max_depth': 15, 'min_samples_split': 2, 'n_e...
# 11  {'max_depth': 15, 'min_samples_split': 5, 'n_e...
# 12  {'max_depth': 15, 'min_samples_split': 10, 'n_...
# 13  {'max_depth': 15, 'min_samples_split': 15, 'n_...
# 14  {'max_depth': 15, 'min_samples_split': 100, 'n...
# 15  {'max_depth': 25, 'min_samples_split': 2, 'n_e...
# 16  {'max_depth': 25, 'min_samples_split': 5, 'n_e...
# 17  {'max_depth': 25, 'min_samples_split': 10, 'n_...
# 18  {'max_depth': 25, 'min_samples_split': 15, 'n_...
# 19  {'max_depth': 25, 'min_samples_split': 100, 'n...
# 20  {'max_depth': 30, 'min_samples_split': 2, 'n_e...
# 21  {'max_depth': 30, 'min_samples_split': 5, 'n_e...
# 22  {'max_depth': 30, 'min_samples_split': 10, 'n_...
# 23  {'max_depth': 30, 'min_samples_split': 15, 'n_...
# 24  {'max_depth': 30, 'min_samples_split': 100, 'n...

# %%
# examine the first result
print("**examine the first result","\n")

print(bestF.cv_results_['params'][0])
print(bestF.cv_results_['mean_test_score'][0])

# print the array of mean scores only
print("\n","**print the array of mean scores only","\n")

grid_mean_scores = bestF.cv_results_['mean_test_score']
print(grid_mean_scores)

# examine the best model
print("\n","**examine the best model","\n")

print(bestF.best_score_)
print(bestF.best_params_)
print(bestF.best_estimator_)
# Out:
# **examine the first result
#
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}
# 0.9878284447797793
#
#  **print the array of mean scores only
#
# [0.98782844 0.98804584 0.98761153 0.98717627 0.98782797 0.98782844
#  0.98782844 0.98739366 0.98739366 0.98804536 0.98739366 0.98717627
#  0.98717627 0.98739366 0.98782797 0.98717627 0.98717627 0.98717627
#  0.98739366 0.98782797 0.98717627 0.98717627 0.98717627 0.98739366
#  0.98782797]
#
#  **examine the best model
#
# 0.9880458360841271
# {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 400}
# RandomForestClassifier(max_depth=5, min_samples_split=5, n_estimators=400,
#                        random_state=1)

# %%
#Print the tured parameters and score
print("Tuned Decision Tree Parameters: {}".format(bestF.best_params_))
print("Best score is {}".format(bestF.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'max_depth': 5, 'min_samples_split': 5, 'n_estimators': 400}
# Best score is 0.9880458360841271

# %% [markdown]
# # setting parameters

# %%
forestOpt = RandomForestClassifier(random_state = 1, max_depth = 5, n_estimators = 400, min_samples_split = 5) #เปลี่ยนตาม cell 8
             
modelOpt = forestOpt.fit(X, y)#

# %%
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVvalidation_5FP_RF_5FP_fold8_1.csv') #เปลี่ยนชื่อไฟล์ Validation

# %%
dataframe
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0             0  1.198032 -0.200516 -0.204294 -0.098968  0.135859  0.004413
# 1             1 -0.069592  0.329786  0.300990  0.388246  0.010353  0.018634
# 2             2 -0.163759 -0.195470  0.191713  0.411987  0.244497 -0.056774
# 3             3  0.289818  0.765759  0.541988  0.247122  0.225844 -0.130515
# 4             4 -0.068669 -0.013692  0.440784  0.404373  0.197310 -0.138683
# ..          ...       ...       ...       ...       ...       ...       ...
# 651         651  0.135851 -0.228165 -0.031476 -0.103109 -0.130443 -0.133419
# 652         652  0.232987 -0.068043  0.381478  0.060085 -0.170231  0.096958
# 653         653 -0.109119 -0.208462 -0.161130 -0.058967 -0.074887 -0.152327
# 654         654  0.192751  0.229311  0.078843  0.362329  0.242724 -0.061710
# 655         655  0.537672  0.864819  0.350187  0.646675  0.428021 -0.078360
#
#             6         7         8  ...      2042      2043      2044  \
# 0   -0.184289  0.786509  0.184650  ... -0.196895  1.102819  0.600976
# 1    0.064608  0.151934  0.235241  ... -0.158448 -0.046067 -0.019178
# 2    0.130079 -0.111927  0.434972  ...  0.614593 -0.084680 -0.047273
# 3    0.589063  0.354398 -0.116416  ... -0.163193  0.100586  0.085105
# 4    0.409092 -0.118299  0.761165  ...  0.881634 -0.028804  0.063383
# ..        ...       ...       ...  ...       ...       ...       ...
# 651 -0.012839 -0.168552 -0.204619  ...  0.152588  0.021057 -0.216978
# 652  0.690560 -0.239708 -0.162655  ...  0.602972  0.016599 -0.119977
# 653 -0.137089  0.045530 -0.099612  ... -0.217071  0.158556  0.072848
# 654  0.174097  0.587090  0.244477  ... -0.088734  0.371496  0.328564
# 655  0.433251  0.307170 -0.013609  ... -0.062002  0.365384  0.874640
#
#          2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0    0.143280 -0.082817  0.710184  Abnormal          P31   FP-B       AB01
# 1   -0.125923 -0.094779  0.122836  Abnormal           P2   FP-A       AB01
# 2    0.402002  0.834466 -0.168192  Abnormal          P51   FP-C       AB01
# 3   -0.170757 -0.038185  0.367311  Abnormal           P1   FP-A       AB01
# 4   -0.002162  0.345757 -0.098269  Abnormal          P52   FP-C       AB01
# ..        ...       ...       ...       ...          ...    ...        ...
# 651 -0.147375 -0.225492 -0.196037    Normal          P71   FP-D     Normal
# 652 -0.118134 -0.176198 -0.129231    Normal          P72   FP-D     Normal
# 653  0.424302 -0.016924  0.062385    Normal           P8   FP-E     Normal
# 654 -0.072609  0.017584  0.033128    Normal           P1   FP-A     Normal
# 655 -0.140419  0.159525  0.835519    Normal           P1   FP-A     Normal
#
# [656 rows x 2053 columns]

# %%
X_test = dataframe.iloc[:,1:2049]
y_test = dataframe.iloc[:,2051]
print(X_test.shape)
print(y_test.shape)
# Out:
# (656, 2048)
# (656,)

# %%
y_test
# Out:
# 0      FP-B
# 1      FP-A
# 2      FP-C
# 3      FP-A
# 4      FP-C
#        ...
# 651    FP-D
# 652    FP-D
# 653    FP-E
# 654    FP-A
# 655    FP-A
# Name: Views, Length: 656, dtype: object

# %%
y_pred = modelOpt.predict(X_test)

# %%
#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))#performance
# Out:
# [[115  12   3   0   0]
#  [  6 193   4   0   1]
#  [  1   9 169   8   1]
#  [  0   0   7  93   0]
#  [  0   4   0   0  30]]
#               precision    recall  f1-score   support
#
#         FP-A       0.94      0.88      0.91       130
#         FP-B       0.89      0.95      0.91       204
#         FP-C       0.92      0.90      0.91       188
#         FP-D       0.92      0.93      0.93       100
#         FP-E       0.94      0.88      0.91        34
#
#     accuracy                           0.91       656
#    macro avg       0.92      0.91      0.91       656
# weighted avg       0.92      0.91      0.91       656

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
#TN, FP, FN, TP = confusion_matrix(y_test, y_pred).ravel()
#print(TN, FP, FN, TP)

# %% [markdown]
# # Save Model

# %%
#Save Model

import pickle
os.chdir('/media/tohn/SSD/ModelTrainByImages/R2_8/models/')
filename = "modelrf_5FP_5FP_fold8_1.pkl" #เปลี่ยนชื่อไฟล์ Train random forest
with open(filename, 'wb') as file:
    pickle.dump(modelOpt, file)

# %%
# #load model

# with open(filename, 'rb') as file:
#     model = pickle.load(file)
