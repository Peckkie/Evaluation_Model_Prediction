# %%
import os
import numpy as np
import pandas as pd
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVtrain_5FP_RF_5FP_fold1_1.csv') #เปลี่ยนไฟล์
dataframe = dataframe.drop(['Unnamed: 0'], axis=1)
dataframe
# Out:
#              0         1         2         3         4         5         6  \
# 0    -0.183173 -0.142023  0.171233  0.104783 -0.138406 -0.141667  0.453777
# 1     0.069722  0.112049  0.256392  0.569649  0.438293 -0.076159  0.737939
# 2     0.043814  0.052640  0.775385  0.753716  0.062080 -0.130202  1.288857
# 3    -0.177954 -0.061284  0.522400  0.189064 -0.201108 -0.214785  0.600988
# 4    -0.185300 -0.005447 -0.178134 -0.163120 -0.194233 -0.114838 -0.174666
# ...        ...       ...       ...       ...       ...       ...       ...
# 4596  0.389022  0.303796 -0.201080 -0.154215 -0.053249  0.508389 -0.186184
# 4597  0.077332  0.019907 -0.178789 -0.170673  0.014434  0.193679 -0.191617
# 4598 -0.198021 -0.169015  0.565406  0.414600 -0.183889 -0.196547  0.649491
# 4599 -0.193998 -0.178347  0.232987  0.250824  0.070464 -0.215060  0.165299
# 4600  0.060093 -0.204639 -0.217259 -0.204298  0.393240 -0.219038 -0.205358
#
#              7         8         9  ...      2042      2043      2044  \
# 0    -0.085352  0.123714 -0.196879  ...  0.227270 -0.169472 -0.107976
# 1    -0.044623 -0.176660  0.109250  ... -0.138969  0.387509 -0.174216
# 2    -0.029463 -0.121414  0.103574  ... -0.207620  0.167637 -0.054157
# 3    -0.189746  0.018161 -0.191795  ...  0.134973 -0.143402 -0.184654
# 4     0.455459  0.201526 -0.073980  ... -0.163250  0.517986  0.012802
# ...        ...       ...       ...  ...       ...       ...       ...
# 4596  0.672725 -0.111990  0.511201  ... -0.176340  0.919878  0.924155
# 4597  0.578476  0.155005  0.223425  ... -0.194791  0.321300  0.449924
# 4598 -0.149529  0.394370 -0.218253  ...  0.286358 -0.190014 -0.197364
# 4599 -0.015401  0.174173 -0.107838  ...  0.820966 -0.060872 -0.204116
# 4600 -0.193412  0.240406  0.221991  ...  0.273275  0.303687 -0.170588
#
#           2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0     0.048568  0.207895 -0.152509  Abnormal          P52   FP-C       AB01
# 1    -0.133051 -0.114128  1.337209  Abnormal           P1   FP-A       AB02
# 2    -0.104977  0.108655  1.534377  Abnormal           P2   FP-A       AB02
# 3     0.454986  0.312115 -0.127496  Abnormal          P51   FP-C       AB02
# 4     0.184158  0.373908 -0.160096  Abnormal          P42   FP-B       AB02
# ...        ...       ...       ...       ...          ...    ...        ...
# 4596 -0.045925 -0.141010 -0.030481    Normal          P32   FP-B     Normal
# 4597 -0.041723  0.031667  0.093323    Normal          P42   FP-B     Normal
# 4598  0.461874  0.340785 -0.181225    Normal          P52   FP-C     Normal
# 4599  0.512624  0.199866 -0.122076    Normal          P61   FP-C     Normal
# 4600  0.151418 -0.238233  0.243049    Normal           P8   FP-E     Normal
#
# [4601 rows x 2052 columns]

# %%
X = dataframe.iloc[:,0:2048]
y = dataframe.iloc[:,2048]
print(X.shape)
print(y.shape)
# Out:
# (4601, 2048)
# (4601,)

# %%
y[0]
# Out:
# 'Abnormal'

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier

# %%
n_estimators = [400]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100] 

forest = RandomForestClassifier(random_state = 1)


hyperF ={'n_estimators' : n_estimators, 'max_depth' : max_depth, 'min_samples_split' : min_samples_split}
# hyperF ={'max_depth' : max_depth, 'min_samples_split' : min_samples_split}

gridF = GridSearchCV(forest, hyperF, cv = 10, verbose = 1, n_jobs = -1)
bestF = gridF.fit(X, y)
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits

# %%
# view the results as a pandas DataFrame
import pandas as pd
pd.DataFrame(bestF.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#     mean_test_score  std_test_score  \
# 0          0.738094        0.051455
# 1          0.737877        0.052902
# 2          0.737225        0.054343
# 3          0.734834        0.050705
# 4          0.732444        0.053722
# 5          0.765913        0.055612
# 6          0.771347        0.058612
# 7          0.764609        0.055487
# 8          0.768087        0.057079
# 9          0.756567        0.059720
# 10         0.791338        0.063691
# 11         0.793729        0.063672
# 12         0.792207        0.061164
# 13         0.793730        0.064099
# 14         0.769171        0.064720
# 15         0.799816        0.064721
# 16         0.797424        0.065581
# 17         0.798292        0.065273
# 18         0.794816        0.063655
# 19         0.774169        0.064102
# 20         0.798729        0.066585
# 21         0.796556        0.067570
# 22         0.797203        0.066936
# 23         0.796336        0.062030
# 24         0.775037        0.064332
#
#                                                params
# 0   {'max_depth': 5, 'min_samples_split': 2, 'n_es...
# 1   {'max_depth': 5, 'min_samples_split': 5, 'n_es...
# 2   {'max_depth': 5, 'min_samples_split': 10, 'n_e...
# 3   {'max_depth': 5, 'min_samples_split': 15, 'n_e...
# 4   {'max_depth': 5, 'min_samples_split': 100, 'n_...
# 5   {'max_depth': 8, 'min_samples_split': 2, 'n_es...
# 6   {'max_depth': 8, 'min_samples_split': 5, 'n_es...
# 7   {'max_depth': 8, 'min_samples_split': 10, 'n_e...
# 8   {'max_depth': 8, 'min_samples_split': 15, 'n_e...
# 9   {'max_depth': 8, 'min_samples_split': 100, 'n_...
# 10  {'max_depth': 15, 'min_samples_split': 2, 'n_e...
# 11  {'max_depth': 15, 'min_samples_split': 5, 'n_e...
# 12  {'max_depth': 15, 'min_samples_split': 10, 'n_...
# 13  {'max_depth': 15, 'min_samples_split': 15, 'n_...
# 14  {'max_depth': 15, 'min_samples_split': 100, 'n...
# 15  {'max_depth': 25, 'min_samples_split': 2, 'n_e...
# 16  {'max_depth': 25, 'min_samples_split': 5, 'n_e...
# 17  {'max_depth': 25, 'min_samples_split': 10, 'n_...
# 18  {'max_depth': 25, 'min_samples_split': 15, 'n_...
# 19  {'max_depth': 25, 'min_samples_split': 100, 'n...
# 20  {'max_depth': 30, 'min_samples_split': 2, 'n_e...
# 21  {'max_depth': 30, 'min_samples_split': 5, 'n_e...
# 22  {'max_depth': 30, 'min_samples_split': 10, 'n_...
# 23  {'max_depth': 30, 'min_samples_split': 15, 'n_...
# 24  {'max_depth': 30, 'min_samples_split': 100, 'n...

# %%
# examine the first result
print("**examine the first result","\n")

print(bestF.cv_results_['params'][0])
print(bestF.cv_results_['mean_test_score'][0])

# print the array of mean scores only
print("\n","**print the array of mean scores only","\n")

grid_mean_scores = bestF.cv_results_['mean_test_score']
print(grid_mean_scores)

# examine the best model
print("\n","**examine the best model","\n")

print(bestF.best_score_)
print(bestF.best_params_)
print(bestF.best_estimator_)
# Out:
# **examine the first result
#
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}
# 0.738094407243233
#
#  **print the array of mean scores only
#
# [0.73809441 0.73787749 0.73722484 0.73483401 0.73244365 0.76591342
#  0.77134726 0.7646086  0.76808686 0.75656701 0.79133783 0.79372866
#  0.79220739 0.79373008 0.76917099 0.79981562 0.79742431 0.79829152
#  0.79481562 0.7741691  0.79872866 0.79655569 0.79720315 0.79633594
#  0.77503678]
#
#  **examine the best model
#
# 0.7998156182212582
# {'max_depth': 25, 'min_samples_split': 2, 'n_estimators': 400}
# RandomForestClassifier(max_depth=25, n_estimators=400, random_state=1)

# %%
#Print the tured parameters and score
print("Tuned Decision Tree Parameters: {}".format(bestF.best_params_))
print("Best score is {}".format(bestF.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'max_depth': 25, 'min_samples_split': 2, 'n_estimators': 400}
# Best score is 0.7998156182212582

# %% [markdown]
# # setting parameters

# %%
forestOpt = RandomForestClassifier(random_state = 1, max_depth = 25, n_estimators = 400, min_samples_split = 2) #เปลี่ยนตาม cell 8
             
modelOpt = forestOpt.fit(X, y)#

# %%
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVvalidation_5FP_RF_5FP_fold1_1.csv') #เปลี่ยนชื่อไฟล์ Validation

# %%
dataframe
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0             0  0.688897  0.481626 -0.204084 -0.138992  0.126013  0.171552
# 1             1  0.208008  0.388320 -0.060117  0.012548 -0.023876  0.121292
# 2             2 -0.110854 -0.097531  0.228024  0.128375  0.112170 -0.180179
# 3             3 -0.165665 -0.149694 -0.207559 -0.110953 -0.129356 -0.048947
# 4             4  0.065224  0.377894 -0.216202  0.032931  0.103808  0.274854
# ..          ...       ...       ...       ...       ...       ...       ...
# 651         651 -0.001885  0.366141 -0.134316 -0.086942  0.048504  0.060465
# 652         652  0.307874  0.290790 -0.201437 -0.076088  0.101540  0.364822
# 653         653 -0.130830 -0.194390  0.296620  0.076171 -0.141220 -0.211505
# 654         654 -0.183827 -0.189500  0.591210  0.176304 -0.118079 -0.211749
# 655         655 -0.162594 -0.224709 -0.214556 -0.195334  0.263479 -0.218074
#
#             6         7         8  ...      2042      2043      2044  \
# 0   -0.202214  0.925737  0.272961  ... -0.188816  1.155643  0.912801
# 1    0.201185  0.655834  0.022517  ... -0.194895  0.525116  0.281003
# 2    0.644814 -0.026187 -0.169307  ... -0.220559  0.162742  0.027353
# 3   -0.213745  0.377276 -0.037325  ... -0.195455  0.059976  0.276703
# 4   -0.208061  0.745532  0.233987  ... -0.220736  0.710436  0.574746
# ..        ...       ...       ...  ...       ...       ...       ...
# 651 -0.179588  0.403197  0.261491  ... -0.049399  0.636152  0.190962
# 652 -0.158874  0.974933  0.055018  ... -0.209186  0.228965  0.872954
# 653  0.549289 -0.187334  0.343873  ...  0.406596 -0.168600 -0.159442
# 654  0.586772 -0.205030  0.465309  ...  0.698599 -0.143482 -0.209706
# 655 -0.207036 -0.142317  0.195464  ...  0.031128  0.213056 -0.180540
#
#          2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0    0.129452  0.003164  0.183335  Abnormal          P31   FP-B       AB01
# 1   -0.047486 -0.037712  0.421807  Abnormal           P1   FP-A       AB01
# 2   -0.079745 -0.221458  0.937575  Abnormal           P2   FP-A       AB01
# 3    0.018258 -0.154483 -0.044068  Abnormal          P42   FP-B       AB01
# 4    0.210663  0.163345 -0.089435  Abnormal          P41   FP-B       AB01
# ..        ...       ...       ...       ...          ...    ...        ...
# 651  0.282361 -0.086646  0.049916    Normal          P32   FP-B     Normal
# 652  0.003071  0.047800  0.217753    Normal          P42   FP-B     Normal
# 653  0.115177  0.315634 -0.140471    Normal          P52   FP-C     Normal
# 654  0.413641  0.047328 -0.079114    Normal          P61   FP-C     Normal
# 655  0.296128 -0.213855 -0.039795    Normal           P8   FP-E     Normal
#
# [656 rows x 2053 columns]

# %%
X_test = dataframe.iloc[:,1:2049]
y_test = dataframe.iloc[:,2049]
print(X_test.shape)
print(y_test.shape)
# Out:
# (656, 2048)
# (656,)

# %%
y_test
# Out:
# 0      Abnormal
# 1      Abnormal
# 2      Abnormal
# 3      Abnormal
# 4      Abnormal
#          ...
# 651      Normal
# 652      Normal
# 653      Normal
# 654      Normal
# 655      Normal
# Name: Class, Length: 656, dtype: object

# %%
y_pred = modelOpt.predict(X_test)

# %%
#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))#performance
# Out:
# [[125 102]
#  [ 24 405]]
#               precision    recall  f1-score   support
#
#     Abnormal       0.84      0.55      0.66       227
#       Normal       0.80      0.94      0.87       429
#
#     accuracy                           0.81       656
#    macro avg       0.82      0.75      0.77       656
# weighted avg       0.81      0.81      0.80       656

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
TN, FP, FN, TP = confusion_matrix(y_test, y_pred).ravel()
print(TN, FP, FN, TP)
# Out:
# 125 102 24 405

# %% [markdown]
# # Save Model

# %%
#Save Model

import pickle
os.chdir('/media/tohn/SSD/ModelTrainByImages/R2_1/models/')
filename = "modelrf_5FP_AN_fold1_1.pkl" #เปลี่ยนชื่อไฟล์ Train random forest
with open(filename, 'wb') as file:
    pickle.dump(modelOpt, file)

# %%
# #load model

# with open(filename, 'rb') as file:
#     model = pickle.load(file)
