# %%
import os
import numpy as np
import pandas as pd
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVtrain_5FP_RF_5FP_fold3_1.csv') #เปลี่ยนไฟล์
dataframe = dataframe.drop(['Unnamed: 0'], axis=1)
dataframe
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.454635  0.385466 -0.184786 -0.028337 -0.053728 -0.153055 -0.194530
# 1    -0.032596  0.273318 -0.174448  0.491713  0.028845  0.026885  0.706252
# 2    -0.130007 -0.176651 -0.167547  0.592732  0.117312 -0.016051  0.808872
# 3    -0.016664 -0.189828 -0.199131 -0.174706 -0.138387 -0.204502 -0.210086
# 4     0.777053  0.669774 -0.181162 -0.017197 -0.140167 -0.047103 -0.187592
# ...        ...       ...       ...       ...       ...       ...       ...
# 4593  0.428170 -0.148052 -0.209006 -0.062886 -0.161224 -0.211183 -0.203773
# 4594  0.277539  0.267934 -0.082643 -0.114626 -0.148996  0.051271 -0.164587
# 4595 -0.187532 -0.175039  0.569313  0.093905  0.506204 -0.105238  0.091066
# 4596 -0.197281 -0.201513  0.530801  0.517311  0.690652 -0.194849  0.121112
# 4597 -0.191222 -0.181634 -0.235690 -0.066846  0.345429 -0.201480 -0.219562
#
#              7         8         9  ...      2042      2043      2044  \
# 0     0.648894  0.435559  0.533567  ...  0.066778  1.025149  0.743229
# 1     0.480919 -0.003031  0.310332  ... -0.155087  0.280151  0.304668
# 2     0.016193 -0.181890 -0.048170  ... -0.174331  0.012112 -0.003200
# 3     0.073383 -0.106316  0.100140  ... -0.211068  0.351206  0.207486
# 4     0.614855  0.332440  0.779578  ... -0.201471  1.124767  0.949034
# ...        ...       ...       ...  ...       ...       ...       ...
# 4593  0.391663 -0.003610  0.546784  ... -0.189382  0.632477  0.314648
# 4594  0.386695  0.030218  0.591794  ... -0.174160  0.392934  0.944996
# 4595 -0.173115  0.134328 -0.229321  ...  0.409509 -0.198020 -0.203667
# 4596 -0.151347  0.140172 -0.195687  ...  0.754076 -0.171817 -0.119111
# 4597 -0.165167  0.354347 -0.121273  ... -0.146057  0.041801 -0.169983
#
#           2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0     0.056678  0.280485  0.841494  Abnormal          P31   FP-B       AB01
# 1    -0.105795 -0.149101 -0.020991  Abnormal           P1   FP-A       AB01
# 2    -0.066616 -0.228609  0.291835  Abnormal           P2   FP-A       AB01
# 3    -0.132347  0.176357  0.114247  Abnormal          P42   FP-B       AB01
# 4    -0.155360  0.101219  0.577824  Abnormal          P41   FP-B       AB01
# ...        ...       ...       ...       ...          ...    ...        ...
# 4593 -0.166028 -0.153261 -0.050434    Normal          P32   FP-B     Normal
# 4594 -0.093637 -0.022131  0.527060    Normal          P42   FP-B     Normal
# 4595  0.362160  0.385033 -0.079242    Normal          P52   FP-C     Normal
# 4596  0.310864  0.384140  0.499897    Normal          P61   FP-C     Normal
# 4597  0.843654 -0.238394  0.970016    Normal           P8   FP-E     Normal
#
# [4598 rows x 2052 columns]

# %%
X = dataframe.iloc[:,0:2048]
y = dataframe.iloc[:,2050]
print(X.shape)
print(y.shape)
# Out:
# (4598, 2048)
# (4598,)

# %%
y[0]
# Out:
# 'FP-B'

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import BaggingClassifier

# %%
n_estimators = [400]
max_depth = [5, 8, 15, 25, 30]
min_samples_split = [2, 5, 10, 15, 100] 

forest = RandomForestClassifier(random_state = 1)


hyperF ={'n_estimators' : n_estimators, 'max_depth' : max_depth, 'min_samples_split' : min_samples_split}
# hyperF ={'max_depth' : max_depth, 'min_samples_split' : min_samples_split}

gridF = GridSearchCV(forest, hyperF, cv = 10, verbose = 1, n_jobs = -1)
bestF = gridF.fit(X, y)
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits

# %%
# view the results as a pandas DataFrame
import pandas as pd
pd.DataFrame(bestF.cv_results_)[['mean_test_score', 'std_test_score', 'params']]
# Out:
#     mean_test_score  std_test_score  \
# 0          0.986954        0.017847
# 1          0.986954        0.017847
# 2          0.986737        0.017752
# 3          0.986954        0.017847
# 4          0.986954        0.017793
# 5          0.985867        0.017747
# 6          0.986085        0.017719
# 7          0.986085        0.017719
# 8          0.986302        0.017715
# 9          0.986954        0.017740
# 10         0.985867        0.017747
# 11         0.986085        0.017878
# 12         0.986085        0.017719
# 13         0.986085        0.017719
# 14         0.986954        0.017740
# 15         0.985867        0.017747
# 16         0.986085        0.017878
# 17         0.986085        0.017719
# 18         0.986085        0.017719
# 19         0.986954        0.017740
# 20         0.985867        0.017747
# 21         0.986085        0.017878
# 22         0.986085        0.017719
# 23         0.986085        0.017719
# 24         0.986954        0.017740
#
#                                                params
# 0   {'max_depth': 5, 'min_samples_split': 2, 'n_es...
# 1   {'max_depth': 5, 'min_samples_split': 5, 'n_es...
# 2   {'max_depth': 5, 'min_samples_split': 10, 'n_e...
# 3   {'max_depth': 5, 'min_samples_split': 15, 'n_e...
# 4   {'max_depth': 5, 'min_samples_split': 100, 'n_...
# 5   {'max_depth': 8, 'min_samples_split': 2, 'n_es...
# 6   {'max_depth': 8, 'min_samples_split': 5, 'n_es...
# 7   {'max_depth': 8, 'min_samples_split': 10, 'n_e...
# 8   {'max_depth': 8, 'min_samples_split': 15, 'n_e...
# 9   {'max_depth': 8, 'min_samples_split': 100, 'n_...
# 10  {'max_depth': 15, 'min_samples_split': 2, 'n_e...
# 11  {'max_depth': 15, 'min_samples_split': 5, 'n_e...
# 12  {'max_depth': 15, 'min_samples_split': 10, 'n_...
# 13  {'max_depth': 15, 'min_samples_split': 15, 'n_...
# 14  {'max_depth': 15, 'min_samples_split': 100, 'n...
# 15  {'max_depth': 25, 'min_samples_split': 2, 'n_e...
# 16  {'max_depth': 25, 'min_samples_split': 5, 'n_e...
# 17  {'max_depth': 25, 'min_samples_split': 10, 'n_...
# 18  {'max_depth': 25, 'min_samples_split': 15, 'n_...
# 19  {'max_depth': 25, 'min_samples_split': 100, 'n...
# 20  {'max_depth': 30, 'min_samples_split': 2, 'n_e...
# 21  {'max_depth': 30, 'min_samples_split': 5, 'n_e...
# 22  {'max_depth': 30, 'min_samples_split': 10, 'n_...
# 23  {'max_depth': 30, 'min_samples_split': 15, 'n_...
# 24  {'max_depth': 30, 'min_samples_split': 100, 'n...

# %%
# examine the first result
print("**examine the first result","\n")

print(bestF.cv_results_['params'][0])
print(bestF.cv_results_['mean_test_score'][0])

# print the array of mean scores only
print("\n","**print the array of mean scores only","\n")

grid_mean_scores = bestF.cv_results_['mean_test_score']
print(grid_mean_scores)

# examine the best model
print("\n","**examine the best model","\n")

print(bestF.best_score_)
print(bestF.best_params_)
print(bestF.best_estimator_)
# Out:
# **examine the first result
#
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}
# 0.986954153642133
#
#  **print the array of mean scores only
#
# [0.98695415 0.98695415 0.98673676 0.98695415 0.98695415 0.9858672
#  0.98608459 0.98608459 0.98630198 0.98695415 0.9858672  0.98608459
#  0.98608459 0.98608459 0.98695415 0.9858672  0.98608459 0.98608459
#  0.98608459 0.98695415 0.9858672  0.98608459 0.98608459 0.98608459
#  0.98695415]
#
#  **examine the best model
#
# 0.986954153642133
# {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}
# RandomForestClassifier(max_depth=5, n_estimators=400, random_state=1)

# %%
#Print the tured parameters and score
print("Tuned Decision Tree Parameters: {}".format(bestF.best_params_))
print("Best score is {}".format(bestF.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'max_depth': 5, 'min_samples_split': 2, 'n_estimators': 400}
# Best score is 0.986954153642133

# %% [markdown]
# # setting parameters

# %%
forestOpt = RandomForestClassifier(random_state = 1, max_depth = 5, n_estimators = 400, min_samples_split = 2) #เปลี่ยนตาม cell 8
             
modelOpt = forestOpt.fit(X, y)#

# %%
dataframe = pd.read_csv( '/home/yupaporn/codes/USAI/FVvalidation_5FP_RF_5FP_fold3_1.csv') #เปลี่ยนชื่อไฟล์ Validation

# %%
dataframe
# Out:
#      Unnamed: 0         0         1         2         3         4         5  \
# 0             0  0.188532 -0.047441 -0.168838  0.728658  0.000519 -0.003455
# 1             1 -0.006571  0.014793 -0.176853  0.606617  0.316530 -0.089578
# 2             2  0.177404  0.126656 -0.093616 -0.122005 -0.171927  0.061711
# 3             3  0.480672  0.525893 -0.172063 -0.141628 -0.168183 -0.028055
# 4             4  0.192721  0.334142 -0.115672 -0.183799 -0.142817 -0.160351
# ..          ...       ...       ...       ...       ...       ...       ...
# 654         654 -0.057390  0.084477 -0.217496 -0.116127 -0.081675 -0.137184
# 655         655 -0.134893 -0.200768  0.011119 -0.103123 -0.080820 -0.222754
# 656         656 -0.150188 -0.123747  0.825877  0.565167  0.166168 -0.075069
# 657         657 -0.150128 -0.201827  0.646323  0.095885  0.178855 -0.173337
# 658         658 -0.082651 -0.093088 -0.184809 -0.199892  0.098515 -0.208339
#
#             6         7         8  ...      2042      2043      2044  \
# 0    0.480539  0.215165 -0.023124  ... -0.087559  0.159215  0.209597
# 1    0.589092  0.097659  0.007992  ...  0.030109  0.070383  0.015577
# 2   -0.205301  0.531099  0.110309  ... -0.175719  0.165019  1.120391
# 3   -0.191895  0.911586  0.373280  ... -0.117175  0.383021  0.843416
# 4   -0.167166  0.688249  0.688450  ... -0.154547  0.879700  0.872571
# ..        ...       ...       ...  ...       ...       ...       ...
# 654 -0.209960  0.537810  0.499916  ... -0.218834  0.713361  0.306790
# 655 -0.183681 -0.138792 -0.077820  ... -0.201104 -0.196536 -0.118417
# 656  0.659950 -0.151828  0.021551  ...  0.838238 -0.036277 -0.184894
# 657  0.140056 -0.207301  0.275641  ...  0.661115 -0.159826 -0.141053
# 658 -0.175032 -0.126291  0.484196  ... -0.071085  0.096150 -0.169943
#
#          2045      2046      2047     Class  SubPosition  Views  Sub_class
# 0   -0.116422 -0.203395  0.050259  Abnormal           P2   FP-A       AB01
# 1    0.014575 -0.106606  0.071525  Abnormal           P1   FP-A       AB01
# 2   -0.035404  0.569768  0.723989  Abnormal          P42   FP-B       AB01
# 3    0.010577  0.430299  0.493947  Abnormal          P31   FP-B       AB01
# 4    0.012714  0.169017  0.261547  Abnormal          P41   FP-B       AB01
# ..        ...       ...       ...       ...          ...    ...        ...
# 654 -0.103926 -0.086212  0.010381    Normal          P32   FP-B     Normal
# 655 -0.111505  0.116904 -0.110684    Normal          P42   FP-B     Normal
# 656  0.207254  0.173992 -0.034786    Normal          P52   FP-C     Normal
# 657 -0.062882  0.650089 -0.051381    Normal          P61   FP-C     Normal
# 658  0.417389 -0.076645  0.397265    Normal           P8   FP-E     Normal
#
# [659 rows x 2053 columns]

# %%
X_test = dataframe.iloc[:,1:2049]
y_test = dataframe.iloc[:,2051]
print(X_test.shape)
print(y_test.shape)
# Out:
# (659, 2048)
# (659,)

# %%
y_test
# Out:
# 0      FP-A
# 1      FP-A
# 2      FP-B
# 3      FP-B
# 4      FP-B
#        ...
# 654    FP-B
# 655    FP-B
# 656    FP-C
# 657    FP-C
# 658    FP-E
# Name: Views, Length: 659, dtype: object

# %%
y_pred = modelOpt.predict(X_test)

# %%
#Marking the Confusion Matrix
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))#performance
# Out:
# [[116  14   1   2   0]
#  [  5 193   6   0   1]
#  [  3   3 173  10   0]
#  [  0   2   3  92   0]
#  [  1   6   0   0  28]]
#               precision    recall  f1-score   support
#
#         FP-A       0.93      0.87      0.90       133
#         FP-B       0.89      0.94      0.91       205
#         FP-C       0.95      0.92      0.93       189
#         FP-D       0.88      0.95      0.92        97
#         FP-E       0.97      0.80      0.88        35
#
#     accuracy                           0.91       659
#    macro avg       0.92      0.90      0.91       659
# weighted avg       0.92      0.91      0.91       659

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(y_test, y_pred)

import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(cm, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# Text(0.5, 21.5, 'Predicted label')

# %%
#TN, FP, FN, TP = confusion_matrix(y_test, y_pred).ravel()
#print(TN, FP, FN, TP)

# %% [markdown]
# # Save Model

# %%
#Save Model

import pickle
os.chdir('/media/tohn/SSD/ModelTrainByImages/R2_3/models/')
filename = "modelrf_5FP_5FP_fold3_1.pkl" #เปลี่ยนชื่อไฟล์ Train random forest
with open(filename, 'wb') as file:
    pickle.dump(modelOpt, file)

# %%
# #load model

# with open(filename, 'rb') as file:
#     model = pickle.load(file)
