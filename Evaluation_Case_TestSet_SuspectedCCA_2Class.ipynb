# %% [markdown]
# <a href="https://colab.research.google.com/github/Peckkie/Evaluation_Model_Prediction/blob/main/Evaluation_Case_TestSet_SuspectedCCA_2Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Suspected CCA
# - pdf(PDF1, PDF2, PDF3)
# - mass (Livermass)
# - BDD(BDD, IHDStone)
# > - AB05: PDF1
# > - AB06: PDF2
# > - AB07: PDF3
# > - AB081: Livermass
# > - AB082: BDD, IHDStone
#
# **แบบ 1: 2 Class**
# 1. 3 CCA Class
#
# 2. 12AB+Normal Class

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
RFdf = pd.read_csv('/content/drive/MyDrive/USAI/Testdf_15ABrf.csv')
RFdf
# Out:
#       Unnamed: 0  ...  Predict_15AB
# 0              0  ...     Incorrect
# 1              1  ...       Correct
# 2              2  ...     Incorrect
# 3              3  ...       Correct
# 4              4  ...     Incorrect
# ...          ...  ...           ...
# 1307        1307  ...       Correct
# 1308        1308  ...       Correct
# 1309        1309  ...       Correct
# 1310        1310  ...       Correct
# 1311        1311  ...       Correct
#
# [1312 rows x 25 columns]

# %%
RFdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1312 entries, 0 to 1311
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     1312 non-null   int64
#  1   Case           1312 non-null   int64
#  2   Abs Position   1312 non-null   object
#  3   Sub Position   1312 non-null   object
#  4   Class          1312 non-null   object
#  5   Sub_class      1312 non-null   object
#  6   Path Full      1312 non-null   object
#  7   Path Crop      1312 non-null   object
#  8   Views          1312 non-null   object
#  9   fold           1312 non-null   int64
#  10  tagName        1312 non-null   object
#  11  originalImage  455 non-null    object
#  12  left           455 non-null    float64
#  13  top            455 non-null    float64
#  14  width          455 non-null    float64
#  15  height         455 non-null    float64
#  16  Rleft          455 non-null    float64
# ...

# %%
Suspected_CCA = ['AB05', 'AB06', 'AB07', 'AB081', 'AB082', 'AB083']

# %%
a_ = RFdf['15AB_category'].tolist()
AI_Predic =[]
for  i in range(len(a_)):
    if a_[i] in Suspected_CCA:
        a = 'SuspectedCCA'
        AI_Predic.append(a)
    else:
        a = 'Non_SuspectedCCA'
        AI_Predic.append(a)

a_ = RFdf['Sub_class'].tolist()
Act_Predic =[]
for  i in range(len(a_)):
    if a_[i] in Suspected_CCA:
        a = 'SuspectedCCA'
        Act_Predic.append(a)
    else:
        a = 'Non_SuspectedCCA'
        Act_Predic.append(a) 

RFdf['AI_Predic_CCA'] = AI_Predic
RFdf['Act_Predic_CCA'] = Act_Predic

RFdf
# Out:
#       Unnamed: 0  Case  ...     AI_Predic_CCA    Act_Predic_CCA
# 0              0    40  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1              1    40  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 2              2    40  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 3              3    40  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 4              4    40  ...  Non_SuspectedCCA  Non_SuspectedCCA
# ...          ...   ...  ...               ...               ...
# 1307        1307   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1308        1308   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1309        1309   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1310        1310   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1311        1311   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
#
# [1312 rows x 27 columns]

# %%
G_sus = RFdf.groupby(['Case', 'AI_Predic_CCA']).count()
G_sus

# %%
G_sus.groupby('AI_Predic_CCA').count()
# Out:
#                   Unnamed: 0  Abs Position  ...  Predict_15AB  Act_Predic_CCA
# AI_Predic_CCA                               ...
# Non_SuspectedCCA         142           142  ...           142             142
# SuspectedCCA              33            33  ...            33              33
#
# [2 rows x 25 columns]

# %%
#case = df['Case'].value_counts()
#case

# %%
#type(case)

# %%
#df_case = pd.DataFrame(case)
#df_case

# %%
#df_case.info()

# %%
df_g = RFdf.groupby('Case').count()
df_g
# Out:
#       Unnamed: 0  Abs Position  ...  AI_Predic_CCA  Act_Predic_CCA
# Case                            ...
# 1             49            49  ...             49              49
# 2             46            46  ...             46              46
# 3             12            12  ...             12              12
# 4             26            26  ...             26              26
# 7             13            13  ...             13              13
# ...          ...           ...  ...            ...             ...
# 440            1             1  ...              1               1
# 441            1             1  ...              1               1
# 442            1             1  ...              1               1
# 443            1             1  ...              1               1
# 458            1             1  ...              1               1
#
# [144 rows x 26 columns]

# %%
df_g_re = df_g.reset_index(level=['Case'])
df_g_re
# Out:
#      Case  Unnamed: 0  ...  AI_Predic_CCA  Act_Predic_CCA
# 0       1          49  ...             49              49
# 1       2          46  ...             46              46
# 2       3          12  ...             12              12
# 3       4          26  ...             26              26
# 4       7          13  ...             13              13
# ..    ...         ...  ...            ...             ...
# 139   440           1  ...              1               1
# 140   441           1  ...              1               1
# 141   442           1  ...              1               1
# 142   443           1  ...              1               1
# 143   458           1  ...              1               1
#
# [144 rows x 27 columns]

# %%
#df_g2 = df.groupby(['Case', 'Class']).count()
#df_g2

# %%
#df_g2_re = df_g2.reset_index(level=['Case', 'Class'])
#df_g2_re

# %%
#c1 = df[(df['Case'] == 3)].reset_index(drop=True)
#for i in range(len(c1)):
 #   if c1['Class'][i] == 'Abnormal':
  #     c1['Class'] = 'Abnormal'
    #elif c1['Class'][i] = 'Normal':
     #    c1['Class'] = 'Normal'

# %%
#c1

# %%
#c1.groupby(['Case', 'Class']).count()

# %%
#df

# %%
list_case = df_g_re['Case'].tolist()
print(len(list_case))
list_case
# Out:
# 144
# [1,
#  2,
#  3,
#  4,
#  7,
#  9,
#  18,
#  25,
#  28,
#  29,
#  30,
#  32,
#  34,
#  40,
#  44,
#  47,
#  50,
#  54,
#  58,
#  65,
#  66,
#  67,
#  68,
#  69,
#  70,
#  80,
#  86,
#  90,
#  91,
#  92,
#  93,
#  94,
#  99,
#  100,
#  101,
#  102,
#  103,
#  113,
#  114,
#  120,
#  121,
#  122,
#  123,
#  124,
#  135,
#  136,
#  140,
#  141,
#  142,
#  143,
#  150,
#  154,
#  155,
#  160,
#  161,
#  162,
#  163,
#  172,
#  173,
#  180,
#  181,
#  182,
#  183,
#  192,
#  193,
#  200,
#  201,
#  204,
#  205,
#  206,
#  207,
#  209,
#  210,
#  219,
#  220,
#  224,
#  225,
#  226,
#  227,
#  229,
#  230,
#  239,
#  240,
#  241,
#  242,
#  244,
#  245,
#  246,
#  247,
#  251,
#  259,
#  260,
#  261,
#  262,
#  279,
#  280,
#  281,
#  282,
#  284,
#  285,
#  286,
#  287,
#  296,
#  299,
#  300,
#  301,
#  302,
#  308,
#  309,
#  310,
#  319,
#  320,
#  321,
#  322,
#  327,
#  329,
#  339,
#  340,
#  341,
#  342,
#  343,
#  350,
#  359,
#  360,
#  361,
#  362,
#  380,
#  381,
#  382,
# ...

# %%
col_name_all = []
for col in RFdf.columns:
    col_name = col
    col_name_all.append(col_name)
col_name_all
# Out:
# ['Unnamed: 0',
#  'Case',
#  'Abs Position',
#  'Sub Position',
#  'Class',
#  'Sub_class',
#  'Path Full',
#  'Path Crop',
#  'Views',
#  'fold',
#  'tagName',
#  'originalImage',
#  'left',
#  'top',
#  'width',
#  'height',
#  'Rleft',
#  'Rtop',
#  'Rwidth',
#  'Rheight',
#  'filename',
#  '15AB_category',
#  '15AB_Prob',
#  '15AB_ProbAll',
#  'Predict_15AB',
#  'AI_Predic_CCA',
#  'Act_Predic_CCA']

# %%
df_case_change = pd.DataFrame(columns = col_name_all)
df_case_change['CCA_tranf'] = ''
df_case_change
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Case, Abs Position, Sub Position, Class, Sub_class, Path Full, Path Crop, Views, fold, tagName, originalImage, left, top, width, height, Rleft, Rtop, Rwidth, Rheight, filename, 15AB_category, 15AB_Prob, 15AB_ProbAll, Predict_15AB, AI_Predic_CCA, Act_Predic_CCA, CCA_tranf]
# Index: []

# %%
for j in list_case :
    c1 = RFdf[(RFdf['Case'] == j)].reset_index(drop=True)
    for i in range(len(c1)):
        if c1['AI_Predic_CCA'][i] == 'SuspectedCCA':
           c1['CCA_tranf'] = 'SuspectedCCA'
    df_case_change = df_case_change.append(c1).reset_index(drop=True)
       # else :
        #  c1['Class_tranf'] = c1['Class'][i]
    #df_case_change = df_case_change.append(c1).reset_index(drop=True)

# %%
df_case_change
# Out:
#      Unnamed: 0 Case  ...    Act_Predic_CCA     CCA_tranf
# 0           179    1  ...  Non_SuspectedCCA  SuspectedCCA
# 1           180    1  ...  Non_SuspectedCCA  SuspectedCCA
# 2           181    1  ...  Non_SuspectedCCA  SuspectedCCA
# 3           182    1  ...  Non_SuspectedCCA  SuspectedCCA
# 4           183    1  ...  Non_SuspectedCCA  SuspectedCCA
# ...         ...  ...  ...               ...           ...
# 1307        445  440  ...  Non_SuspectedCCA           NaN
# 1308        432  441  ...  Non_SuspectedCCA           NaN
# 1309        448  442  ...  Non_SuspectedCCA           NaN
# 1310        443  443  ...  Non_SuspectedCCA           NaN
# 1311        430  458  ...  Non_SuspectedCCA           NaN
#
# [1312 rows x 28 columns]

# %%
df_case_change["CCA_tranf"].fillna("Non_SuspectedCCA", inplace = True)

# %%
df_case_change.groupby(['Case', 'CCA_tranf']).count()
# Out:
#                        Unnamed: 0  Abs Position  ...  AI_Predic_CCA  Act_Predic_CCA
# Case CCA_tranf                                   ...
# 1    SuspectedCCA              49            49  ...             49              49
# 2    SuspectedCCA              46            46  ...             46              46
# 3    Non_SuspectedCCA          12            12  ...             12              12
# 4    SuspectedCCA              26            26  ...             26              26
# 7    Non_SuspectedCCA          13            13  ...             13              13
# ...                           ...           ...  ...            ...             ...
# 440  Non_SuspectedCCA           1             1  ...              1               1
# 441  Non_SuspectedCCA           1             1  ...              1               1
# 442  Non_SuspectedCCA           1             1  ...              1               1
# ...

# %%
 pd.isnull(df_case_change["CCA_tranf"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1307    False
# 1308    False
# 1309    False
# 1310    False
# 1311    False
# Name: CCA_tranf, Length: 1312, dtype: bool

# %%
##### actul ############

# %%
df_case_acc = pd.DataFrame(columns = col_name_all)
df_case_acc['Act_CCA_tranf'] = ''
df_case_acc
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Case, Abs Position, Sub Position, Class, Sub_class, Path Full, Path Crop, Views, fold, tagName, originalImage, left, top, width, height, Rleft, Rtop, Rwidth, Rheight, filename, 15AB_category, 15AB_Prob, 15AB_ProbAll, Predict_15AB, AI_Predic_CCA, Act_Predic_CCA, Act_CCA_tranf]
# Index: []

# %%
for j in list_case :
    c1 = RFdf[(RFdf['Case'] == j)].reset_index(drop=True)
    for i in range(len(c1)):
        if c1['Act_Predic_CCA'][i] == 'SuspectedCCA':
           c1['Act_CCA_tranf'] = 'SuspectedCCA'
    df_case_acc = df_case_acc.append(c1).reset_index(drop=True)

# %%
df_case_acc["Act_CCA_tranf"].fillna("Non_SuspectedCCA", inplace = True)
df_case_acc
# Out:
#      Unnamed: 0 Case  ...    Act_Predic_CCA     Act_CCA_tranf
# 0           179    1  ...  Non_SuspectedCCA      SuspectedCCA
# 1           180    1  ...  Non_SuspectedCCA      SuspectedCCA
# 2           181    1  ...  Non_SuspectedCCA      SuspectedCCA
# 3           182    1  ...  Non_SuspectedCCA      SuspectedCCA
# 4           183    1  ...  Non_SuspectedCCA      SuspectedCCA
# ...         ...  ...  ...               ...               ...
# 1307        445  440  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1308        432  441  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1309        448  442  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1310        443  443  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1311        430  458  ...  Non_SuspectedCCA  Non_SuspectedCCA
#
# [1312 rows x 28 columns]

# %%
df_case_acc.groupby(['Case', 'Act_CCA_tranf']).count()
# Out:
#                        Unnamed: 0  Abs Position  ...  AI_Predic_CCA  Act_Predic_CCA
# Case Act_CCA_tranf                               ...
# 1    SuspectedCCA              49            49  ...             49              49
# 2    SuspectedCCA              46            46  ...             46              46
# 3    Non_SuspectedCCA          12            12  ...             12              12
# 4    SuspectedCCA              26            26  ...             26              26
# 7    Non_SuspectedCCA          13            13  ...             13              13
# ...                           ...           ...  ...            ...             ...
# 440  Non_SuspectedCCA           1             1  ...              1               1
# 441  Non_SuspectedCCA           1             1  ...              1               1
# 442  Non_SuspectedCCA           1             1  ...              1               1
# ...

# %%
pd.isnull(df_case_acc["Act_CCA_tranf"])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1307    False
# 1308    False
# 1309    False
# 1310    False
# 1311    False
# Name: Act_CCA_tranf, Length: 1312, dtype: bool

# %%
RFdf['AiCase_Cca2Class'] = df_case_change["CCA_tranf"]
RFdf['ActCase_Cca2class'] = df_case_acc["Act_CCA_tranf"]
RFdf
# Out:
#       Unnamed: 0  Case  ...  AiCase_Cca2Class ActCase_Cca2class
# 0              0    40  ...      SuspectedCCA      SuspectedCCA
# 1              1    40  ...      SuspectedCCA      SuspectedCCA
# 2              2    40  ...      SuspectedCCA      SuspectedCCA
# 3              3    40  ...      SuspectedCCA      SuspectedCCA
# 4              4    40  ...      SuspectedCCA      SuspectedCCA
# ...          ...   ...  ...               ...               ...
# 1307        1307   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1308        1308   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1309        1309   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1310        1310   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
# 1311        1311   350  ...  Non_SuspectedCCA  Non_SuspectedCCA
#
# [1312 rows x 29 columns]

# %%
#RFdf.to_csv('/content/drive/MyDrive/USAI/PredictCase1312Cca_2Class.csv')

# %%
AN_tranf = df_case_change.groupby(['Case', 'CCA_tranf']).count()
AN_tranf2 = AN_tranf.reset_index(level=['Case', 'CCA_tranf'])
df_AN_tranf2 = AN_tranf2[['Case','CCA_tranf']]
df_AN_tranf2
# Out:
#      Case         CCA_tranf
# 0       1      SuspectedCCA
# 1       2      SuspectedCCA
# 2       3  Non_SuspectedCCA
# 3       4      SuspectedCCA
# 4       7  Non_SuspectedCCA
# ..    ...               ...
# 139   440  Non_SuspectedCCA
# 140   441  Non_SuspectedCCA
# 141   442  Non_SuspectedCCA
# 142   443  Non_SuspectedCCA
# 143   458  Non_SuspectedCCA
#
# [144 rows x 2 columns]

# %%
Class_tranf = df_case_acc.groupby(['Case', 'Act_CCA_tranf']).count()
Class_tranf

# %%
#AN_tranf = df_case_change.groupby(['Case', 'AN_tranf']).count()
#AN_tranf2 = AN_tranf.reset_index(level=['Case', 'AN_tranf'])
#df_AN_tranf2 = AN_tranf2[['Case','AN_tranf']]
#Class_tranf = df_case_acc.groupby(['Case', 'Class_tranf']).count()
Class_tranf2 = Class_tranf.reset_index(level=['Case', 'Act_CCA_tranf'])
#Class_tranf2
df_Class_tranf2 = Class_tranf2[['Case','Act_CCA_tranf']]
df_Class_tranf2
# Out:
#      Case     Act_CCA_tranf
# 0       1      SuspectedCCA
# 1       2      SuspectedCCA
# 2       3  Non_SuspectedCCA
# 3       4      SuspectedCCA
# 4       7  Non_SuspectedCCA
# ..    ...               ...
# 139   440  Non_SuspectedCCA
# 140   441  Non_SuspectedCCA
# 141   442  Non_SuspectedCCA
# 142   443  Non_SuspectedCCA
# 143   458  Non_SuspectedCCA
#
# [144 rows x 2 columns]

# %%
df_Class_tranf2['Act_CCA_tranf'].value_counts()
# Out:
# Non_SuspectedCCA    112
# SuspectedCCA         32
# Name: Act_CCA_tranf, dtype: int64

# %%
case_AN = df_AN_tranf2['Case'].tolist()
case_class = df_Class_tranf2['Case'].tolist()

# %%
for i, j in zip(case_AN, case_AN) :
    if i == j :
       print(i, j,'Case ตรงกัน')
    else :
       print(i, j,'Case ไม่ตรงกัน')
   
print('Prediction len = ',len(case_AN))
print('Actul len = ',len(case_AN))
# Out:
# 1 1 Case ตรงกัน
# 2 2 Case ตรงกัน
# 3 3 Case ตรงกัน
# 4 4 Case ตรงกัน
# 7 7 Case ตรงกัน
# 9 9 Case ตรงกัน
# 18 18 Case ตรงกัน
# 25 25 Case ตรงกัน
# 28 28 Case ตรงกัน
# 29 29 Case ตรงกัน
# 30 30 Case ตรงกัน
# 32 32 Case ตรงกัน
# 34 34 Case ตรงกัน
# 40 40 Case ตรงกัน
# 44 44 Case ตรงกัน
# 47 47 Case ตรงกัน
# 50 50 Case ตรงกัน
# 54 54 Case ตรงกัน
# 58 58 Case ตรงกัน
# 65 65 Case ตรงกัน
# 66 66 Case ตรงกัน
# 67 67 Case ตรงกัน
# 68 68 Case ตรงกัน
# 69 69 Case ตรงกัน
# 70 70 Case ตรงกัน
# 80 80 Case ตรงกัน
# 86 86 Case ตรงกัน
# 90 90 Case ตรงกัน
# 91 91 Case ตรงกัน
# 92 92 Case ตรงกัน
# 93 93 Case ตรงกัน
# 94 94 Case ตรงกัน
# 99 99 Case ตรงกัน
# 100 100 Case ตรงกัน
# 101 101 Case ตรงกัน
# 102 102 Case ตรงกัน
# 103 103 Case ตรงกัน
# 113 113 Case ตรงกัน
# 114 114 Case ตรงกัน
# 120 120 Case ตรงกัน
# 121 121 Case ตรงกัน
# 122 122 Case ตรงกัน
# 123 123 Case ตรงกัน
# 124 124 Case ตรงกัน
# 135 135 Case ตรงกัน
# 136 136 Case ตรงกัน
# 140 140 Case ตรงกัน
# 141 141 Case ตรงกัน
# 142 142 Case ตรงกัน
# ...

# %%
merge = df_Class_tranf2.merge(df_AN_tranf2, how='inner', on='Case')
merge
# Out:
#      Case     Act_CCA_tranf         CCA_tranf
# 0       1      SuspectedCCA      SuspectedCCA
# 1       2      SuspectedCCA      SuspectedCCA
# 2       3  Non_SuspectedCCA  Non_SuspectedCCA
# 3       4      SuspectedCCA      SuspectedCCA
# 4       7  Non_SuspectedCCA  Non_SuspectedCCA
# ..    ...               ...               ...
# 139   440  Non_SuspectedCCA  Non_SuspectedCCA
# 140   441  Non_SuspectedCCA  Non_SuspectedCCA
# 141   442  Non_SuspectedCCA  Non_SuspectedCCA
# 142   443  Non_SuspectedCCA  Non_SuspectedCCA
# 143   458  Non_SuspectedCCA  Non_SuspectedCCA
#
# [144 rows x 3 columns]

# %%
#merge.rename({'Class_Class': 'Case_Class', 'AN_tranf': 'Case_category'}, axis=1, inplace=True)
#merge

# %%
#merge.to_csv('/content/drive/MyDrive/USAI/PredictCase144Cca_2Class.csv')

# %%
#วัดผล 
import numpy as np
from sklearn.metrics import confusion_matrix

act = merge['Act_CCA_tranf'].array
pred = merge['CCA_tranf'].array
cmat = confusion_matrix(act, pred)
print('classifier accuracy = {}%'.format((100.*np.trace(cmat))/(np.sum(cmat))))

from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(act, pred))#performance
# Out:
# classifier accuracy = 97.91666666666667%
#                   precision    recall  f1-score   support
#
# Non_SuspectedCCA       0.99      0.98      0.99       112
#     SuspectedCCA       0.94      0.97      0.95        32
#
#         accuracy                           0.98       144
#        macro avg       0.97      0.98      0.97       144
#     weighted avg       0.98      0.98      0.98       144

# %%
#create CF 
data = {'Actual': act,'Predicted' : pred,}
df = pd.DataFrame(data, columns=['Actual','Predicted'])
conf_mat = pd.crosstab(df['Actual'],df['Predicted'],rownames=['Actual'],colnames=['Predicted'])

#Confusion matrix
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
cm = confusion_matrix(act, pred)
print(cm)
#plot Confusion matrix
import seaborn as sns
sns.set()
fig, ax = plt.subplots(figsize=(8, 5))

ax = sns.heatmap(conf_mat, annot=True, fmt="d", cmap="YlGnBu") #Blues,Oranges,Reds
ax.set_title('Confusion matrix',fontsize=20)
ax.set_ylabel('True label',fontsize=18)
ax.set_xlabel('Predicted label',fontsize=18)
# Out:
# [[110   2]
#  [  1  31]]
# Text(0.5, 20.59375, 'Predicted label')
